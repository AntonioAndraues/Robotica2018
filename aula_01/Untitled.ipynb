# %%
# %matplotlib inline
import cv2
import cv2 as cv
from matplotlib import pyplot as plt
import numpy as np
import time as t

# %%
img=cv.imread("antonio.png",0)

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'r')
plt.hist(img.flatten(),256,[0,256], color = 'g')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-47-35af263923a7> in <module>()
# ----> 1 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#
# error: /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/color.cpp:11079: error: (-215) scn == 3 || scn == 4 in function cvtColor

# %%
plt.imshow(img_rgb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-18ea6105591c> in <module>()
# ----> 1 plt.imshow(img_rgb)
#
# NameError: name 'img_rgb' is not defined

# %%
img_r=img_rgb[:,:,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-b1282795e83d> in <module>()
# ----> 1 img_r=img_rgb[:,:,2]
#
# NameError: name 'img_rgb' is not defined

# %%
plt.imshow(img_r, cmap='Greys_r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-43200a0e7047> in <module>()
# ----> 1 plt.imshow(img_r, cmap='Greys_r')
#
# NameError: name 'img_r' is not defined
